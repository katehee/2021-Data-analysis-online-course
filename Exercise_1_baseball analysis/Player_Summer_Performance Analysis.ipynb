# %%
import pandas as pd

file  = './KBO_2019_player_gamestats.xlsx'
raw = pd.read_excel(file)
raw.head()
# Out:
#      Team   Name        DOB       Date Opponent  Result  GS  AB  R  H  ...  \
# 0  Doosan  페르난데스 1988-04-27 2021-03-23   Hanhwa   W 5:4   1   4  0  2  ...
# 1  Doosan  페르난데스 1988-04-27 2021-03-24   Hanhwa  L 1:11   1   2  0  0  ...
# 2  Doosan  페르난데스 1988-04-27 2021-03-26   kiwoom   W 7:2   1   2  2  0  ...
# 3  Doosan  페르난데스 1988-04-27 2021-03-27   kiwoom   W 3:2   1   4  1  3  ...
# 4  Doosan  페르난데스 1988-04-27 2021-03-28   kiwoom   L 4:5   1   3  1  0  ...
#
#    SH  SF    AVG    OBP    SLG    OPS  DIPS  avLI  RE24    WPA
# 0   0   0  0.500  0.500  0.750  1.250    19  1.98  1.65  0.429
# 1   0   0  0.333  0.333  0.500  0.833     4  0.77 -0.36 -0.038
# 2   0   0  0.250  0.400  0.375  0.775    16  1.56  0.98  0.146
# 3   0   0  0.417  0.500  0.500  1.000    11  1.53  1.29  0.189
# 4   0   0  0.333  0.474  0.400  0.874    23  2.04 -0.30 -0.166
#
# [5 rows x 31 columns]

# %% [markdown]
# # Q) Who's performance is steady regardless of weather (esp. hot summer)
# - monthly record

# %%
#extract only month from 'Date' and create separate 'month' column 
month_list = []
for monthdate in raw['Date']:
    month = monthdate.month
    month_list.append(month)
raw['Month'] = month_list

# %%
#select columns for analysis
columns_select = ['Team', 'Name', 'DOB','Date', 'Opponent','AB','H','HR', 'TB', 'RBI','BB', 'HBP', 'SF', 'Month']

data = raw[columns_select]
data.head()
# Out:
#      Team   Name        DOB       Date Opponent  AB  H  HR  TB  RBI  BB  HBP  \
# 0  Doosan  페르난데스 1988-04-27 2021-03-23   Hanhwa   4  2   0   3    3   0    0
# 1  Doosan  페르난데스 1988-04-27 2021-03-24   Hanhwa   2  0   0   0    0   0    0
# 2  Doosan  페르난데스 1988-04-27 2021-03-26   kiwoom   2  0   0   0    1   2    0
# 3  Doosan  페르난데스 1988-04-27 2021-03-27   kiwoom   4  3   0   3    1   0    0
# 4  Doosan  페르난데스 1988-04-27 2021-03-28   kiwoom   3  0   0   0    0   2    0
#
#    SF  Month
# 0   0      3
# 1   0      3
# 2   0      3
# 3   0      3
# 4   0      3

# %%
#Using pivot table, view monthly performance  
data_player_month = data.pivot_table(index = ['Team','Name','DOB', 'Month'], 
                               values = ['AB','H','HR','TB','RBI','BB','HBP','SF'], 
                              aggfunc = 'sum', fill_value = 0
                                )
data_player_month
# Out:
#                               AB  BB   H  HBP  HR  RBI  SF  TB
# Team   Name DOB        Month
# Doosan 국해성  1989-10-08 3       2   1   0    1   0    0   0   0
#                        4       1   0   0    0   0    0   0   0
#                        5      21   2   4    0   0    2   0   6
#                        6       3   1   0    0   0    0   0   0
#                        8       6   1   0    0   0    0   0   0
# ...                           ..  ..  ..  ...  ..  ...  ..  ..
# lotte  허일   1992-11-20 5      71   8  18    1   0    8   0  19
#                        6      24   2   6    0   0    1   0   6
#                        8      10   1   2    0   0    0   0   3
#                        9      18   0   4    0   0    2   0   4
#        황진수  1989-02-15 5       3   1   0    0   0    0   0   0
#
# [1261 rows x 8 columns]

# %%
data_player_month = data_player_month.reset_index()
data_player_month
# Out:
#         Team Name        DOB  Month  AB  BB   H  HBP  HR  RBI  SF  TB
# 0     Doosan  국해성 1989-10-08      3   2   1   0    1   0    0   0   0
# 1     Doosan  국해성 1989-10-08      4   1   0   0    0   0    0   0   0
# 2     Doosan  국해성 1989-10-08      5  21   2   4    0   0    2   0   6
# 3     Doosan  국해성 1989-10-08      6   3   1   0    0   0    0   0   0
# 4     Doosan  국해성 1989-10-08      8   6   1   0    0   0    0   0   0
# ...      ...  ...        ...    ...  ..  ..  ..  ...  ..  ...  ..  ..
# 1256   lotte   허일 1992-11-20      5  71   8  18    1   0    8   0  19
# 1257   lotte   허일 1992-11-20      6  24   2   6    0   0    1   0   6
# 1258   lotte   허일 1992-11-20      8  10   1   2    0   0    0   0   3
# 1259   lotte   허일 1992-11-20      9  18   0   4    0   0    2   0   4
# 1260   lotte  황진수 1989-02-15      5   3   1   0    0   0    0   0   0
#
# [1261 rows x 12 columns]
