# %%
import folium

# %% [markdown]
# # Mapping
# - Create a map
#     - `m` = folium.Map(location = [latitude, longitude],  zoom_start = zoom scale)
#
# - Add information
#     - Add a marker
#         - folium.Marker([latitude, longitude]).add_to(`m`)
#     - Add a circle
#         -     folium.CircleMarker([latitude, longitude],radius= circle size).add_to(`m`)
#     - Additional options:
#         - tooltip="cursor message"
#         - popup="message to be appeared when clicked"
#     - ex) ClickForMarker('CheckPoint').add_to(`m`)

# %%
# Create a map
# Set latitude and longitude boundary  
# zoom_start: set zoom scale 
m = folium.Map(location=[43.653963,-79.387207],   #Toronto)
               zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Add a marker
folium.Marker([43.653963,-79.387207],    # Toronto location
              tooltip="Toronto(cursor msg)",
              popup="Toronto(clicked msg)",
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# Circle marker 
folium.CircleMarker([43.653963,-79.387207],
                    radius=20,
                    tooltip = 'cursor msg'
               ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Minimap()

# %%
from folium.plugins import MiniMap

# Create a map
m = folium.Map(location=[43.653963,-79.387207],   # 기준좌표: 서울역
               zoom_start=12)

# Create a Mini map
minimap = MiniMap() 
minimap.add_to(m)


# Add a marker
folium.Marker([43.653963,-79.387207],    # 서울역위치
#               tooltip="Toronto(cursor)",
#               popup="Toronto(clicked)",
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### folium.ClickForMarker : Add markers by clicking on the map

# %%
# Create a map
m = folium.Map(location=[43.653963,-79.387207],   # 기준좌표: 서울역
               zoom_start=12)

# Add a circle marker
folium.CircleMarker([43.653963,-79.387207],
                    radius=20,
#                     tooltip = 
               ).add_to(m)
folium.ClickForMarker('Marker').add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Create a world map
# - dataset downloaded from kaggle: https://www.kaggle.com/franckepeixoto/countries

# %%
import pandas as pd

# %%
file = './countries.csv'
raw = pd.read_csv(file)
raw.head()
# Out:
#        Country  Importance  Altitude   Latitude  Longitude
# 0  Afghanistan    0.747027       0.0  33.768006  66.238514
# 1      Albania    0.727912       0.0  41.000028  19.999962
# 2      Algeria    0.758319       0.0  28.000027   2.999983
# 3      Andorra    0.779500       0.0  42.540717   1.573203
# 4       Angola    0.831118       0.0 -11.877577  17.569124

# %%
#display index(row) 0 lattitude and longitude
i = 0
lat = raw.loc[i,'Latitude']
long = raw.loc[i,'Longitude']
country = raw.loc[i,'Country']
print(country, lat, long)
# Out:
# Afghanistan 33.7680065 66.2385139

# %%
for i in range(len(raw)):
    lat = raw.loc[i,'Latitude']
    long = raw.loc[i,'Longitude']
    country = raw.loc[i,'Country']
    print(country, lat, long)
# Out:
# Afghanistan 33.7680065 66.2385139
# Albania 41.000028 19.9999619
# Algeria 28.0000272 2.9999825
# Andorra 42.5407167 1.5732033
# Angola -11.8775768 17.5691241
# Antigua and Barbuda 17.2234721 -61.9554608
# Argentina -34.9964963 -64.9672817
# Armenia 40.7696272 44.6736646
# Australia -24.7761086 134.755
# Austria 47.2000338 13.199959
# Azerbaijan 40.3936294 47.7872508
# Bahamas 24.7736546 -78.0000547
# Bahrain 26.1551249 50.5344606
# Bangladesh 24.4768783 90.2932426
# Barbados 13.1500331 -59.5250305
# Belarus 53.4250605 27.6971358
# Belgium 50.6402809 4.6667145
# Belize 16.8259793 -88.7600927
# Benin 9.5293472 2.2584408
# Bhutan 27.549511 90.5119273
# Bolivia -17.0568696 -64.9912286
# Bosnia and Herzegovina 44.3053476 17.5961467
# Botswana -23.1681782 24.5928742
# Brazil -10.3333333 -53.2
# Brunei 4.4137155 114.5653908
# Bulgaria 42.6073975 25.4856617
# Burkina Faso 12.0753083 -1.6880314
# Burma 17.1750495 95.9999652
# Burundi -3.3634357 29.8870575
# Cabo Verde 16.0000552 -24.0083947
# ...

# %%
# Create a map, then add markers
m = folium.Map(location=[33.68357027447924, 17.78557297949212],
               zoom_start=1)
m
# Add markers

for i in range(len(raw)):
    lat = raw.loc[i,'Latitude']
    long = raw.loc[i,'Longitude']
    country = raw.loc[i,'Country']

    folium.Marker([lat, long],tooltip= country).add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## MarkerCluster(): merge adjacent markers into groups

# %%
from folium.plugins import MarkerCluster

# %%
# Create a map
m = folium.Map(location=[33.68357027447924, 17.78557297949212],
               zoom_start=1)
marker_cluster = MarkerCluster().add_to(m)  # create clusters

# Add markers

for i in range(len(raw)):
    lat = raw.loc[i,'Latitude']
    long = raw.loc[i,'Longitude']
    country = raw.loc[i,'Country']
    folium.Marker([lat, long],
                tooltip = country).add_to(marker_cluster)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## MiniMap

# %%
from folium.plugins import MiniMap

# %%
m = folium.Map(location=[33.68357027447924, 17.78557297949212],
               zoom_start=1)
# Create clusters
marker_cluster = MarkerCluster().add_to(m)

# create a Minimap
minimap = MiniMap() 
# m.add_child(minimap)
minimap.add_to(m)

# Add markers
for i in range(len(raw)):
    lat = raw.loc[i,'Latitude']
    long = raw.loc[i,'Longitude']
    country = raw.loc[i,'Country']
    folium.Marker([lat, long], tooltip = country).add_to(marker_cluster)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
